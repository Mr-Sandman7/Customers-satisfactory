# %% [markdown]
# <h1 dir=rtl align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# رضایت مسافران
# </font>
# </h1>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# شاید باورتان نشود اما در برخی از کشورهای دنیا، نظر مسافران برای شرکت‌های هواپیمایی و ارائه‌دهندگان خدمات مسافرتی اهمیت دارد تا بتوانند به‌کمک آن‌ها خدمات خود را بهبود بخشند! 😯
# در این پروژه قصد داریم با استفاده از داده‌های مربوط به رضایت مسافران از خدمات ارائه‌شده توسط شرکت‌های هواپیمایی، مدلی بسازیم که بتواند نظر نهایی مسافران یعنی رضایت یا عدم رضایت را پیش‌بینی کند. همچنین این مجموعه‌داده فرصت خوبی را برای‌تان فراهم می‌کند تا در صورت علاقه، به تمرین بیشتر تحلیل یا مصورسازی داده بپردازید و بینش‌های مفیدی را از داده‌ها استخراج کنید.
# </font>
# </p>

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# دو فایل ‌<code>train.csv</code> و <code>test.csv</code> به‌ترتیب شامل نمونه‌های آموزشی و آزمون هستند. ویژگی‌های اصلی موجود در مجموعه‌داده در جدول زیر شرح داده شده است و ستون <code>satisfaction</code> بیانگر متغیر هدف این مسئله است. طبیعتاً مجموعه‌ی آزمون شامل این ستون نیست و مدل شما باید مقدار این ستون را برای نمونه‌های آزمون پیش‌بینی کند.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# | <b>ستون</b> | <b>توضیحات</b> |
# | :---: | :---: |
# | <code>Gender</code> | جنسیت مسافر |
# | <code>Customer Type</code> | نوع مسافر (از نظر وفاداری) |
# | <code>Age</code> | سن مسافر |
# | <code>Type of Travel</code> | نوع سفر (کاری یا تفریحی) |
# | <code>Class</code> | کلاس پرواز |
# | <code>Flight Distance</code> | مسافت پرواز |
# | <code>Inflight wifi service</code> | رضایت از امکانات وای‌فای در هنگام پرواز (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Departure/Arrival time convenient</code> | رضایت از زمان حرکت/رسیدن پرواز (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Ease of Online booking</code> | رضایت از راحتی رزرو آنلاین (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Gate location</code> | رضایت از موقعیت گِیت پرواز (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Food and drink</code> | رضایت از غذا و نوشیدنی‌های ارائه‌شده (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Online boarding</code> | رضایت از بوردینگ آنلاین (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Seat comfort</code> | رضایت از راحتی صندلی (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Inflight entertainment</code> | رضایت از امکانات سرگرمی در هنگام پرواز (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>On-board service</code> | رضایت از خدمات ارائه‌شده در هنگام پرواز (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Leg room service</code> | رضایت از فضای پا (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Baggage handling</code> | رضایت از خدمات باربری (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Checkin service</code> | رضایت از خدمات چک‌این (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Inflight service</code> | رضایت از خدمات ارائه‌شده در هنگام پرواز (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Cleanliness</code> | رضایت از تمیزی هواپیما (۰ به‌معنی عدم نظر - از ۱ تا ۵) |
# | <code>Departure Delay in Minutes</code> | تاخیر حرکت (دقیقه) |
# | <code>Arrival Delay in Minutes</code> | تاخیر رسیدن (دقیقه) |
# | <code>satisfaction</code> | رضایت مسافران (رضایت: ‌<code>satisfied</code>، عدم رضایت یا خنثی: <code>neutral or dissatisfied</code>) |
#
# </font>
# </div>
# </center>

# %%
# !pip install keras --upgrade
# uncomment the above line if you don't have keras 3 installed
import keras
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# تحلیل داده اکتشافی و پیش‌پردازش
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# از آن‌جا که این مجموعه‌داده شامل ویژگی‌های متعدد و متنوعی است، می‌توانید از جنبه‌های مختلفی به تحلیل داده‌ها بپردازید. برای مثال می‌توانید توزیع‌های ویژگی‌ها را بررسی کنید، ارتباط ویژگی‌ها با هم و با متغیر هدف را بررسی کنید. همچنین با توجه به بینش‌هایی که از داده‌ها به‌دست می‌آورید، می‌توانید به پیش‌پردازش داده‌ها بپردازید تا ورودی‌های باکیفیت‌تری را برای مدل خود آماده کنید. این بخش به‌صورت جداگانه مورد داوری قرار نمی‌گیرد و دست شما باز است تا از هر تکنیکی که برای بهبود عملکرد مدل خود لازم می‌دانید استفاده کنید.
# </font>
# </p>

# %%
# Preprocessing step
train = pd.read_csv('C:\My Codes\Deep Learning\Practices and Projects\satisfaction\data/train.csv')
test = pd.read_csv('C:\My Codes\Deep Learning\Practices and Projects\satisfaction\data/test.csv')

# %%
print(train.shape)
train.head()
# Out:
# (103904, 25)
#    Unnamed: 0      id  Gender   Customer Type  Age   Type of Travel     Class  \
# 0       46021   84772    Male  Loyal Customer   44  Business travel  Business
# 1       94940  120186    Male  Loyal Customer   42  Business travel  Business
# 2        3013  105475  Female  Loyal Customer   42  Business travel  Business
# 3       72514   73109  Female  Loyal Customer   60  Business travel  Business
# 4       60418   49438  Female  Loyal Customer   43  Business travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0             3028                      2                                  2
# 1             1325                      2                                  1
# 2             3336                      3                                  2
# 3             2174                      1                                  5
# 4              421                      5                                  1
#
#    ...  Inflight entertainment  On-board service  Leg room service  \
# 0  ...                       4                 4                 4
# 1  ...                       2                 2                 2
# 2  ...                       4                 4                 4
# 3  ...                       1                 1                 1
# 4  ...                       3                 3                 5
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 4                3                 4            5
# 1                 2                5                 2            4
# 2                 4                5                 4            4
# 3                 1                3                 1            1
# 4                 3                4                 3            5
#
#    Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                           6                       5.0
# 1                           0                       0.0
# 2                           0                       0.0
# 3                           0                       0.0
# 4                           0                       0.0
#
#               satisfaction
# 0                satisfied
# 1                satisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 25 columns]

# %%
for i in train.columns:
    print(i, train[i].unique())
# Out:
# Unnamed: 0 [46021 94940  3013 ...  3736 16281  9979]
# id [ 84772 120186 105475 ...  77841 109370  42888]
# Gender ['Male' 'Female']
# Customer Type ['Loyal Customer' 'disloyal Customer']
# Age [44 42 60 43 70  9 11 55 69 24 50 22 28 34 30 47 18 36 25 37 61 52 45  8
#  23 64 39 53 63 72 20 58 49 38 59 12 17 40 57 29 21 26  7 13 46 31 56 15
#  35 27 32 54 62 19 66 41 71 48 76 51 14 68 33 16 67 10 65 79 75 77 80 74
#  73 78 85]
# Type of Travel ['Business travel' 'Personal Travel']
# Class ['Business' 'Eco' 'Eco Plus']
# Flight Distance [3028 1325 3336 ...  877 1336 1429]
# Inflight wifi service [2 3 1 5 4 0]
# Departure/Arrival time convenient [2 1 5 4 3 0]
# Ease of Online booking [2 3 5 1 0 4]
# Gate location [2 3 5 1 4 0]
# Food and drink [4 3 5 1 2 0]
# Online boarding [4 3 1 2 0 5]
# Seat comfort [5 4 2 1 3 0]
# Inflight entertainment [4 2 1 3 5 0]
# On-board service [4 2 1 3 5 0]


# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for i in ['Gender', 'Customer Type', 'Type of Travel', 'satisfaction']:
    train[i] = le.fit_transform(train[i])
train.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   44               0      2             3028
# 1       1              0   42               0      2             1325
# 2       0              0   42               0      2             3336
# 3       0              0   60               0      2             2174
# 4       0              0   43               0      0              421
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      2                                  2
# 1                      2                                  1
# 2                      3                                  2
# 3                      1                                  5
# 4                      5                                  1
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       2              2  ...                       4
# 1                       2              2  ...                       2
# 2                       3              3  ...                       4
# 3                       5              5  ...                       1
# 4                       1              1  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 4                 4                3
# 1                 2                 2                 2                5
# 2                 4                 4                 4                5
# 3                 1                 1                 1                3
# 4                 3                 5                 3                4
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                           6
# 1                 2            4                           0
# 2                 4            4                           0
# 3                 1            1                           0
# 4                 3            5                           0
#
#    Arrival Delay in Minutes  satisfaction
# 0                       5.0             1
# 1                       0.0             1
# 2                       0.0             1
# 3                       0.0             0
# 4                       0.0             1
#
# [5 rows x 23 columns]

# %%
train.corr().iloc[-1]
# Out:
# Gender                               0.012356
# Customer Type                       -0.187558
# Age                                  0.137040
# Type of Travel                      -0.448995
# Class                                0.494545
# Flight Distance                      0.298915
# Inflight wifi service                0.284163
# Departure/Arrival time convenient   -0.051718
# Ease of Online booking               0.171507
# Gate location                        0.000449
# Food and drink                       0.209659
# Online boarding                      0.503447
# Seat comfort                         0.349112
# Inflight entertainment               0.398203
# On-board service                     0.322450
# Leg room service                     0.313182
# Baggage handling                     0.247819
# Checkin service                      0.235914
# Inflight service                     0.244852
# Cleanliness                          0.305050
# Departure Delay in Minutes          -0.050515
# Arrival Delay in Minutes            -0.057582
# satisfaction                         1.000000
# Name: satisfaction, dtype: float64

# %%
train.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   44               0      2             3028
# 1       1              0   42               0      2             1325
# 2       0              0   42               0      2             3336
# 3       0              0   60               0      2             2174
# 4       0              0   43               0      0              421
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      2                                  2
# 1                      2                                  1
# 2                      3                                  2
# 3                      1                                  5
# 4                      5                                  1
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       2              2  ...                       4
# 1                       2              2  ...                       2
# 2                       3              3  ...                       4
# 3                       5              5  ...                       1
# 4                       1              1  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 4                 4                3
# 1                 2                 2                 2                5
# 2                 4                 4                 4                5
# 3                 1                 1                 1                3
# 4                 3                 5                 3                4
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                           6
# 1                 2            4                           0
# 2                 4            4                           0
# 3                 1            1                           0
# 4                 3            5                           0
#
#    Arrival Delay in Minutes  satisfaction
# 0                       5.0             1
# 1                       0.0             1
# 2                       0.0             1
# 3                       0.0             0
# 4                       0.0             1
#
# [5 rows x 23 columns]

# %%
test.fillna(test['Arrival Delay in Minutes'].mean(), inplace= True)

# %%
test.drop(columns= ['Unnamed: 0', 'id'], inplace= True)
test['Class'] = test['Class'].map(custom_mapping)
le2 = LabelEncoder()
for i in ['Gender', 'Customer Type', 'Type of Travel']:
    test[i] = le2.fit_transform(test[i])
test.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   36               0      2             2137
# 1       1              0   21               1      0              363
# 2       0              1   28               0      2              541
# 3       1              0   50               0      2             3468
# 4       1              0   60               0      2             1183
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  5
# 1                      4                                  4
# 2                      3                                  3
# 3                      5                                  5
# 4                      2                                  1
#
#    Ease of Online booking  Gate location  ...  Seat comfort  \
# 0                       5              5  ...             3
# 1                       4              3  ...             2
# 2                       3              3  ...             4
# 3                       5              5  ...             2
# 4                       1              1  ...             3
#
#    Inflight entertainment  On-board service  Leg room service  \
# 0                       3                 3                 3
# 1                       2                 4                 5
# 2                       3                 4                 2
# 3                       4                 4                 4
# 4                       2                 2                 2
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 3                2                 3            2
# 1                 4                5                 4            2
# 2                 4                5                 5            3
# 3                 4                5                 4            4
# 4                 2                3                 2            3
#
#    Departure Delay in Minutes  Arrival Delay in Minutes
# 0                          14                       0.0
# 1                           0                       0.0
# 2                           1                       6.0
# 3                           2                       0.0
# 4                           3                      28.0
#
# [5 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(train.drop(columns=['satisfaction']), train['satisfaction'], test_size= 0.1, random_state= 4)

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# پس از آماده‌سازی داده‌ها نوبت به ساخت شبکه‌ی عصبی می‌رسد. باز هم دست‌تان باز است تا معماری موردنظر خود را طراحی کنید و از هر تکنیکی که لازم می‌دانید جهت بهتر کردن فرآیند آموزش مدل استفاده کنید. پیشنهاد می‌کنیم تکنیک‌های مختلفی که تا اینجای دوره آموخته‌اید را آزمایش کرده و به تفسیر نتایج بپردازید.
# </font>
# </p>

# %%
model = keras.Sequential()
model.add(keras.layers.Input(shape=(22,)))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Dense(100, activation= 'relu', kernel_initializer= 'he_normal'))
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Dense(50, activation= 'selu', kernel_initializer= 'lecun_normal'))
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Dense(1, activation= 'sigmoid'))

# %%
model.compile(optimizer= 'adam',
              loss= keras.losses.BinaryCrossentropy,
              metrics= ['accuracy'])

# %%
checkpoint = keras.callbacks.ModelCheckpoint('my_best_model.keras', save_best_only= True)

history = model.fit(X_train, y_train,
                    epochs= 50,
                    batch_size= 128,
                    validation_data= [X_valid, y_valid])
                    #callbacks= [checkpoint])
# Out:
# Epoch 1/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8509 - loss: 0.3534 - val_accuracy: 0.9257 - val_loss: 0.1834
# Epoch 2/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9149 - loss: 0.2101 - val_accuracy: 0.9341 - val_loss: 0.1582
# Epoch 3/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9251 - loss: 0.1837 - val_accuracy: 0.9446 - val_loss: 0.1414
# Epoch 4/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9320 - loss: 0.1668 - val_accuracy: 0.9496 - val_loss: 0.1274
# Epoch 5/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9346 - loss: 0.1577 - val_accuracy: 0.9497 - val_loss: 0.1184
# Epoch 6/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9395 - loss: 0.1470 - val_accuracy: 0.9534 - val_loss: 0.1131
# Epoch 7/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9430 - loss: 0.1382 - val_accuracy: 0.9563 - val_loss: 0.1100
# Epoch 8/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9421 - loss: 0.1376 - val_accuracy: 0.9556 - val_loss: 0.1064
# Epoch 9/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9460 - loss: 0.1300 - val_accuracy: 0.9582 - val_loss: 0.1034
# Epoch 10/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9462 - loss: 0.1264 - val_accuracy: 0.9581 - val_loss: 0.1018
# Epoch 11/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9485 - loss: 0.1228 - val_accuracy: 0.9570 - val_loss: 0.1040
# Epoch 12/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9494 - loss: 0.1222 - val_accuracy: 0.9589 - val_loss: 0.1004
# Epoch 13/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9493 - loss: 0.1200 - val_accuracy: 0.9582 - val_loss: 0.1001
# Epoch 14/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9501 - loss: 0.1198 - val_accuracy: 0.9600 - val_loss: 0.0965
# Epoch 15/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9527 - loss: 0.1159 - val_accuracy: 0.9596 - val_loss: 0.0971
# Epoch 16/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9513 - loss: 0.1143 - val_accuracy: 0.9605 - val_loss: 0.0956
# Epoch 17/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9526 - loss: 0.1143 - val_accuracy: 0.9614 - val_loss: 0.0945
# Epoch 18/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.
50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9566 - loss: 0.1015 - val_accuracy: 0.9595 - val_loss: 0.0891
# Epoch 50/50
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9564 - loss: 0.1015 - val_accuracy: 0.9623 - val_loss: 0.0863

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌بینی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در فایل <code>test.csv</code> لیستی از نمونه‌های آزمون در اختیار شما قرار گرفته و نیاز است به‌ازای هر کدام از آن‌ها رضایت یا عدم رضایت مسافر را پیش‌بینی کنید. پیشنهاد می‌کنیم برای اطمینان از عملکرد مدل خود و بهبود آن، ابتدا آن را بر روی یک مجموعه‌ی اعتبارسنجی آزمایش کنید.
# </font>
# </p>
#
#
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معیار ارزیابی
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# برای ارزیابی عملکرد مدل شما بر روی نمونه‌های آزمون از معیار <code>Accuracy</code> استفاده می‌کنیم. این معیار نسبت تعداد پیش‌بینی‌های صحیح مدل به کل نمونه‌های آزمون را نشان می‌دهد.
# </font>
# </p>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font color="red"><b color='red'>توجه:</b></font>
# <font face="vazir" size=3>
#  جهت کسب امتیاز کامل نیاز است تا پاسخ شما حداقل امتیاز <code>96.20</code> را با توجه به معیار معرفی‌شده کسب نماید.
# </font>
# </p>

# %%
y_pred = model.predict(test)
y_pred
# Out:
# 812/812 ━━━━━━━━━━━━━━━━━━━━ 1s 972us/step
# array([[0.0013774 ],
#        [0.29540208],
#        [0.03765644],
#        ...,
#        [0.9999976 ],
#        [0.00555486],
#        [0.24732059]], dtype=float32)

# %%
y_pred = (y_pred > 0.5).astype(int)
y_pred.reshape(-1,)
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# ساختار خروجی برای نمونه‌های آزمون
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#  پیش‌بینی مدل خود را برای نمونه‌های آزمون تولید کرده و در ستون <code>satisfaction</code> دیتافریمی با نام <code>submission</code> ذخیره کنید. توجه داشته باشید که ترتیب مقادیر این ستون باید دقیقاً معادل با ترتیب نمونه‌های آزمون باشد. یعنی مثلاً ردیف اول بیانگر پیش‌بینی مدل برای نمونه‌ی آزمون اول باشد. همچنین مقادیر این ستون باید یکی از دو مقدار <code>satisfied</code> یا <code>neutral or dissatisfied</code> باشد.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |<code>satisfaction</code>|پیش‌بینی مدل از رضایت مسافر (رضایت: ‌<code>satisfied</code>، عدم رضایت یا خنثی: <code>neutral or dissatisfied</code>)|
#
# </font>
# </div>
# </center>

# %%
submission = pd.DataFrame()
submission['satisfaction'] = y_pred.reshape(-1,)
submission['satisfaction'] = submission['satisfaction'].map({0: 'neutral or dissatisfied', 1: 'satisfied'})
submission
# Out:
#                   satisfaction
# 0      neutral or dissatisfied
# 1      neutral or dissatisfied
# 2      neutral or dissatisfied
# 3                    satisfied
# 4      neutral or dissatisfied
# ...                        ...
# 25971  neutral or dissatisfied
# 25972                satisfied
# 25973                satisfied
# 25974  neutral or dissatisfied
# 25975  neutral or dissatisfied
#
# [25976 rows x 1 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد. همچنین اگر از گوگل کولب استفاده می‌کنید، در صورت نیاز به پشتیبانی حتماً آخرین نسخه از نت‌بوک را به‌صورت دستی دانلود کرده و داخل فایل ارسالی قرار دهید یا لینک کولب را با ما به‌اشتراک بگذارید.
# </font>
# </p>

# %%
import zipfile
import joblib
import os

if not os.path.exists(os.path.join(os.getcwd(), 'satisfaction.ipynb')):
    # %notebook -e satisfaction.ipynb

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

submission.to_csv('submission.csv', index=False)
file_names = ['satisfaction.ipynb', 'submission.csv']
compress(file_names)
# Out:
# File Paths:
# ['satisfaction.ipynb', 'submission.csv']
